# %% [markdown]
# # Свёрточные нейронные сети. Часть 1.

# %% [markdown]
# ## Переключение версии TensorFlow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import imageio

import tensorflow as tf

# %% [markdown]
# ## Загрузка и подготовка датасета MNIST

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()
# указываем размер batch (какой объем данных используем для вычисления) = -1 (вычислить самостоятельно), то есть брать все 
# нам всегда нужно иметь канальное измерение, хотя у нас картинка черно-белая мы все равно явно указываем, что канал = 1
train_x = train_x.reshape(-1, 32, 32, 3).astype(np.float32) / 255. 
test_x = test_x.reshape(-1, 32, 32, 3).astype(np.float32) / 255.

print(train_x.shape, train_x.dtype)
print(test_x.shape, test_x.dtype)
print(train_y.shape, train_y.dtype)
print(test_y.shape, test_y.dtype)
# Out:
# (50000, 32, 32, 3) float32
# (10000, 32, 32, 3) float32
# (50000, 1) uint8
# (10000, 1) uint8

# %% [markdown]
# ## Визуализация датасета MNIST

# %%
some_samples = train_x[:32, ...]

fig = plt.figure(figsize=(20, 20))
for j in range(some_samples.shape[0]):
    ax = fig.add_subplot(10, 15, j+1)
    ax.imshow(some_samples[j,:,:,:])
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Создание модели CNN

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# ## Подготовка к обучению

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Обучение модели

# %%
NUM_EPOCHS = 15

model.fit(train_x, train_y, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 256s 164ms/step - loss: 1.6607 - accuracy: 0.3859
# Epoch 2/15
# 1563/1563 [==============================] - 258s 165ms/step - loss: 1.2728 - accuracy: 0.5434
# Epoch 3/15
# 1563/1563 [==============================] - 262s 168ms/step - loss: 1.1088 - accuracy: 0.6068
# Epoch 4/15
# 1563/1563 [==============================] - 255s 163ms/step - loss: 0.9985 - accuracy: 0.6492
# Epoch 5/15
# 1563/1563 [==============================] - 258s 165ms/step - loss: 0.9411 - accuracy: 0.6700
# Epoch 6/15
# 1563/1563 [==============================] - 265s 169ms/step - loss: 0.8871 - accuracy: 0.6887
# Epoch 7/15
# 1563/1563 [==============================] - 254s 162ms/step - loss: 0.8461 - accuracy: 0.7025
# Epoch 8/15
# 1563/1563 [==============================] - 252s 162ms/step - loss: 0.8181 - accuracy: 0.7136
# Epoch 9/15
# 1563/1563 [==============================] - 247s 158ms/step - loss: 0.7902 - accuracy: 0.7240
# Epoch 10/15
# 1563/1563 [==============================] - 248s 159ms/step - loss: 0.7625 - accuracy: 0.7330
# Epoch 11/15
# 1563/1563 [==============================] - 247s 158ms/step - loss: 0.7445 - accuracy: 0.7391
# Epoch 12/15
# 1563/1563 [==============================] - 253s 162ms/step - loss: 0.7277 - accuracy: 0.7466
# Epoch 13/15
# 1563/1563 [==============================] - 251s 161ms/step - loss: 0.7160 - accuracy: 0.7487
# Epoch 14/15
# 1563/1563 [==============================] - 260s 166ms/step - loss: 0.6959 - accuracy: 0.7552
# Epoch 15/15
# 1563/1563 [==============================] - 258s 165ms/step - loss: 0.6833 - accuracy: 0.7599

# %% [markdown]
# ## Оценка качества модели

# %%
model.evaluate(test_x, test_y)
# Out:
# 313/313 [==============================] - 8s 27ms/step - loss: 0.7294 - accuracy: 0.7553
# [0.729405403137207, 0.755299985408783]

# %% [markdown]
# ## Пример инференса модели

# %%
sample = test_x[0, ...]
prediction = model(sample[None, ...])[0]
print(prediction)
# Out:
# tf.Tensor(
# [7.2198873e-04 7.3835207e-04 1.3052447e-03 6.0325539e-01 4.8455849e-04
#  3.6742815e-01 1.1032114e-02 4.4434769e-03 5.5280114e-03 5.0626849e-03], shape=(10,), dtype=float32)

# %% [markdown]
# ## Функция для инференса и отображения результата предсказания

# %%
# setting class names
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
def test_picture(sample):
    
    prediction = model(sample[None, ...])[0]
    ans = np.argmax(prediction)
    
    fig = plt.figure(figsize=(15,7))

    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(sample[:,:,:])
    plt.xticks([]), plt.yticks([])

    ax = fig.add_subplot(1, 2, 2)
    bar_list = ax.bar(class_names, prediction, align='center')
    bar_list[ans].set_color('g')
    ax.set_xticks(np.arange(10))
    ax.set_xlim([-1, 10])
    ax.grid(True)

    plt.show()
    
    print('Predicted object: {}'.format(class_names[ans]))

# %% [markdown]
# ## Запуск предсказания для изображения случайной цифры из MNIST

# %%
import random
idx = random.randint(0, test_x.shape[0])
sample = test_x[idx, ...]
test_picture(sample)

print('True Answer: {}'.format(class_names[test_y[idx][0]]))
# Out:
# Predicted number: truck
# True Answer: truck

# %% [markdown]
# ## Запуск предсказания на нашем изображении

# %%
path = './IMG_3045.jpeg'

# %%
img = imageio.imread(path)
plt.imshow(img)

# %%
from PIL import Image

def make_square(im, min_size=256, fill_color=(0, 0, 0, 0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGB', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

# %%
img = Image.open(path)
img = make_square(img)

# %%
plt.imshow(img)

# %%
#turn to square
def load_and_prepare_image(img):
    import imageio
    from skimage.transform import resize
    #img = imageio.imread(fpath, pilmode="RGB")
    img = np.asarray(img)
    img = img.astype(np.float32)/255
    img = resize(img, (32, 32), order=3, mode='reflect')#
    img = np.reshape(img, (32, 32, -1))
    return img

# %%
img = load_and_prepare_image(img)

# %%
plt.imshow(img)

# %%
test_picture(img)
# Out:
# Predicted object: ship
