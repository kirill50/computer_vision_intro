# %% [markdown]
# # Семантическая Сегментация. Часть 1.

# %% [markdown]
# ## Переключение версии TensorFlow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import random
import imageio
import numpy as np

import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# ## Загрузка данных
# `me_256.png` - Изображение
#
# `me_gt_256.png` - Карта сагментации (человек/фон)

# %%
if 1:
    # !wget https://raw.githubusercontent.com/dkorobchenko-nv/person-segmentation/master/img/me_256.png
    # !wget https://raw.githubusercontent.com/dkorobchenko-nv/person-segmentation/master/img/me_gt_256.png
# Out:
# --2021-02-14 10:38:58--  https://raw.githubusercontent.com/dkorobchenko-nv/person-segmentation/master/img/me_256.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118993 (116K) [image/png]
# Saving to: ‘me_256.png.1’
#
# me_256.png.1        100%[===================>] 116.20K  --.-KB/s    in 0.07s
#
# 2021-02-14 10:38:58 (1.74 MB/s) - ‘me_256.png.1’ saved [118993/118993]
#
# --2021-02-14 10:38:58--  https://raw.githubusercontent.com/dkorobchenko-nv/person-segmentation/master/img/me_gt_256.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2965 (2.9K) [image/png]
# Saving to: ‘me_gt_256.png.1’
#
# me_gt_256.png.1     100%[===================>]   2.90K  --.-KB/s    in 0s
#
# 2021-02-14 10:38:59 (17.8 MB/s) - ‘me_gt_256.png.1’ saved [2965/2965]

# %% [markdown]
# ## Визуализация данных

# %%
img = imageio.imread('me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %%
gt = imageio.imread('me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]
_=plt.imshow(gt[...,0], cmap='gray')

# %% [markdown]
# ## Создание "игрушечного" сегментационного датасета
# Датасет очень маленький, модель скорее всего переобучится.
# Наша цель - проверить работоспособность пайплайна.

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f95e0d76d10>, None)

# %% [markdown]
# ## Создание модели U-Net

# %%
# U-Net
def build_model():
    x = tf.keras.layers.Input((256, 256, 3))
    
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    out1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out1)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out2 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out2)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out3 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out4 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out4)

    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out4, out], axis=3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out3, out], axis=3)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out2, out], axis=3)

    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out1, out], axis=3)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')(out)

    return tf.keras.Model(inputs=x, outputs=out)

model = build_model()

# %% [markdown]
# ## Визуализация U-Net

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Обучение модели

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 1

loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

hist = model.fit(train_x, train_y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS)

plt.plot(hist.history['loss'])
# Out:
# Epoch 1/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.3136
# Epoch 2/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.3853
# Epoch 3/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.2794
# Epoch 4/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1856
# Epoch 5/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1799
# Epoch 6/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1594
# Epoch 7/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1381
# Epoch 8/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1037
# Epoch 9/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.5055
# Epoch 10/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.2260
# Epoch 11/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.2495
# Epoch 12/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.2078
# Epoch 13/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1786
# Epoch 14/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1814
# Epoch 15/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1774
# Epoch 16/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1732
# Epoch 17/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1747
# Epoch 18/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1701
# Epoch 19/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1608
# Epoch 20/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1525
# Epoch 21/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1378
# Epoch 22/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1232
# Epoch 23/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.1084
# Epoch 24/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0967
# Epoch 25/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0842
# Epoch 26/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0716
# Epoch 27/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0732
# Epoch 28/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0689
# Epoch 29/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0601
# Epoch 30/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0549
# Epoch 31/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0475
# Epoch 32/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0446
# Epoch 33/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0379
# Epoch 34/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0335
# Epoch 35/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0305
# Epoch 36/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0308
# Epoch 37/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0257
# Epoch 38/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0296
# Epoch 39/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0269
# Epoch 40/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0231
# Epoch 41/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0213
# Epoch 42/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0215
# Epoch 43/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0193
# Epoch 44/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0179
# Epoch 45/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0182
# Epoch 46/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0192
# Epoch 47/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0263
# Epoch 48/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0461
# Epoch 49/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0207
# Epoch 50/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0538
# Epoch 51/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0382
# Epoch 52/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0537
# Epoch 53/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0494
# Epoch 54/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0229
# Epoch 55/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0312
# Epoch 56/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0246
# Epoch 57/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0249
# Epoch 58/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0222
# Epoch 59/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0194
# Epoch 60/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0154
# Epoch 61/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0160
# Epoch 62/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0169
# Epoch 63/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0147
# Epoch 64/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0139
# Epoch 65/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0141
# Epoch 66/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0126
# Epoch 67/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0116
# Epoch 68/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0102
# Epoch 69/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0107
# Epoch 70/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0103
# Epoch 71/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0087
# Epoch 72/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0089
# Epoch 73/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0082
# Epoch 74/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0075
# Epoch 75/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0072
# Epoch 76/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0069
# Epoch 77/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0063
# Epoch 78/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0060
# Epoch 79/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0058
# Epoch 80/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0056
# Epoch 81/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0054
# Epoch 82/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0053
# Epoch 83/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0051
# Epoch 84/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0047
# Epoch 85/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0045
# Epoch 86/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0043
# Epoch 87/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0045
# Epoch 88/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0045
# Epoch 89/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0045
# Epoch 90/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0091
# Epoch 91/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0138
# Epoch 92/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0118
# Epoch 93/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0126
# Epoch 94/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0125
# Epoch 95/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0107
# Epoch 96/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0149
# Epoch 97/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0085
# Epoch 98/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0095
# Epoch 99/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0068
# Epoch 100/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0066
# Epoch 101/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0068
# Epoch 102/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0060
# Epoch 103/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0056
# Epoch 104/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0052
# Epoch 105/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0048
# Epoch 106/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0046
# Epoch 107/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0044
# Epoch 108/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0043
# Epoch 109/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0042
# Epoch 110/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0041
# Epoch 111/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0038
# Epoch 112/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0037
# Epoch 113/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0036
# Epoch 114/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0036
# Epoch 115/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0034
# Epoch 116/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 117/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 118/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 119/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 120/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 121/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 122/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 123/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 124/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 125/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 126/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 127/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 128/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 129/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 130/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 131/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 132/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 133/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 134/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 135/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 136/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 137/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 138/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 139/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0024
# Epoch 140/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0024
# Epoch 141/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0024
# Epoch 142/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0023
# Epoch 143/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0023
# Epoch 144/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0023
# Epoch 145/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0022
# Epoch 146/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0022
# Epoch 147/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0022
# Epoch 148/150
# 2/2 [==============================] - 2s 1s/step - loss: 0.0022
# Epoch 149/150
# 2/2 [==============================] - 3s 1s/step - loss: 0.0021
# Epoch 150/150
# 2/2 [==============================] - 3s 2s/step - loss: 0.0021

# %% [markdown]
# ## Пример результата сегментации

# %%
out = model.predict(img[None, ...])[0, ...]
_=plt.imshow(out[...,0])

# %% [markdown]
# ## Наложение карты сегментации на изображение

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('viridis')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
