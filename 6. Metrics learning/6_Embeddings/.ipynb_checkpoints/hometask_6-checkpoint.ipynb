# %% [markdown]
# ## Hometask 6
# ## Обучение эмбеддингов (Metric Learning)

# %% [markdown]
# ## Переключение версии TensorFlow

# %%
#%pip uninstall tensorflow -y
#%pip install tensorflow==2.1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import imageio

import tensorflow as tf
import tensorflow_datasets as tfds

# %%
train_ds_unbatched, train_info = tfds.load('lfw', split='train[:80%]', with_info=True)

# %%
INP_SIZE = 224

train_x = []
train_y = []
for k, ds in enumerate(train_ds_unbatched):
    img = ds["image"].numpy().astype(np.float32)/255.
    img = tf.image.resize(img, (INP_SIZE, INP_SIZE))
    train_x.append(img)
    train_y.append(ds["label"].numpy())

# %%
test_ds_unbatched, test_info = tfds.load('lfw', split='train[80%:]', with_info=True)

# %%
INP_SIZE = 224

test_x = []
test_y = []
for k, ds in enumerate(test_ds_unbatched):
    img = ds["image"].numpy().astype(np.float32)/255.
    img = tf.image.resize(img, (INP_SIZE, INP_SIZE))
    test_x.append(img)
    test_y.append(ds["label"].numpy())

# %%
fig = plt.figure(figsize=(10, 10))
for i, image in enumerate(train_x[:16]):
    ax = fig.add_subplot(4, 4, i+1)
    ax.imshow(image)
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Создание модели CNN

# %%
EMB_SIZE = 64

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(EMB_SIZE, activation=None),
])

# %% [markdown]
# ## Contrastive Loss

# %%
MARGIN = 10.0

def contastive_loss(embs, labels):
    bs = embs.shape[0]
    embs1 = embs[:bs//2, :]
    embs2 = embs[bs//2:, :]
    labels1 = labels[:bs//2]
    labels2 = labels[bs//2:]

    d2 = tf.reduce_sum(tf.square(embs1 - embs2), axis=1)
    d =  tf.sqrt(d2)
    z = tf.cast(labels1 == labels2, tf.float32)
    
    return tf.reduce_mean(z * d2 + (1-z) * tf.maximum(0, MARGIN - d)**2)

# %% [markdown]
# ## Подготовка пайплайна данных

# %%
BATCH_SIZE = 10
NUM_EPOCHS = 4

train_ds = tf.data.Dataset.from_tensor_slices((train_x[:100], train_y[:100]))
train_ds = train_ds.shuffle(buffer_size=train_x[0].shape[0])
train_ds = train_ds.repeat(NUM_EPOCHS)
train_ds = train_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## Подготовка к обучению

# %%
LEARNING_RATE = 0.001
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# %% [markdown]
# ## Обучение модели

# %%
# %%time

for iteration, (images, labels) in enumerate(train_ds):
    print(images.shape)
    
    # Forward
    with tf.GradientTape() as tape:
        embs = model(images)
        loss_value = contastive_loss(embs, labels)
        
    # Backward
    grads = tape.gradient(loss_value, model.variables)
    optimizer.apply_gradients(zip(grads, model.variables))

    if iteration % 200 == 0:
        print('[{}] Loss: {}'.format(iteration, loss_value.numpy()))
# Out:
# (10, 224, 224, 3)
# [0] Loss: 0.0
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# (10, 224, 224, 3)
# CPU times: user 1min 24s, sys: 15.1 s, total: 1min 39s
# Wall time: 35.4 s

# %% [markdown]
# ## Получение эмбеддингов для тестовой выборки

# %%
test_embs = model(test_x[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in merge_with(self, other)
#     922       try:
# --> 923         self.assert_same_rank(other)
#     924         new_dims = []
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in assert_same_rank(self, other)
#     977         raise ValueError("Shapes %s and %s must have the same rank" %
# --> 978                          (self, other))
#     979
#
# ValueError: Shapes (224, 224, 3) and (None, None, None, None) must have the same rank
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in with_rank(self, rank)
#    1007     try:
# -> 1008       return self.merge_with(unknown_shape(rank=rank))
#    1009     except ValueError:
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in merge_with(self, other)
#     928       except ValueError:
# --> 929         raise ValueError("Shapes %s and %s are not compatible" % (self, other))
#     930
#
# ValueError: Shapes (224, 224, 3) and (None, None, None, None) are not compatible
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in __init__(self, input_shape, filter_shape, padding, strides, dilation_rate, name, data_format)
#    1064     try:
# -> 1065       input_shape.with_rank(num_spatial_dims + 2)
#    1066     except ValueError:
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in with_rank(self, rank)
#    1009     except ValueError:
# -> 1010       raise ValueError("Shape %s must have rank %d" % (self, rank))
#    1011
#
# ValueError: Shape (224, 224, 3) must have rank 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a8913f7ac426> in <module>
# ----> 1 test_embs = model(test_x[0])
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     279         kwargs['training'] = training
#     280
# --> 281       outputs = layer(inputs, **kwargs)
#     282
#     283       # `outputs` will be the inputs to the next layer.
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/convolutional.py in call(self, inputs)
#     201           strides=self.strides,
#     202           padding=self._padding_op,
# --> 203           data_format=self._conv_op_data_format)
#     204
#     205     # Apply causal padding to inputs for Conv1D.
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in __init__(self, input_shape, filter_shape, padding, strides, dilation_rate, name, data_format)
#    1066     except ValueError:
#    1067       raise ValueError(
# -> 1068           "input tensor must have rank %d" % (num_spatial_dims + 2))
#    1069
#    1070     try:
#
# ValueError: input tensor must have rank 4

# %% [markdown]
# ## Функция для визуализации эмбеддингов

# %%
def draw_embeddings(X_embedded, targets, labels):
    plt.figure(figsize=(10, 10))
    for class_idx in range(np.max(targets)+1):
        X_embedded_class = X_embedded[targets == class_idx, :]
        plt.scatter(X_embedded_class[:,0], X_embedded_class[:,1])
    plt.legend(labels, loc='best')
    plt.grid(True)

# %% [markdown]
# ## Визуализация образцов MNIST в 2D пространстве с помощью TSNE

# %%
test_x_flat = test_x.reshape(-1, 28*28)
test_x_2D = TSNE(n_components=2).fit_transform(test_x_flat[:1000])
labels_for_viz = test_y[:1000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-e49006f343f5> in <module>
# ----> 1 test_x_flat = test_x.reshape(-1, 28*28)
#       2 test_x_2D = TSNE(n_components=2).fit_transform(test_x_flat[:1000])
#       3 labels_for_viz = test_y[:1000]
#
# NameError: name 'test_x' is not defined

# %%
draw_embeddings(test_x_2D, labels_for_viz, list(range(10)))

# %% [markdown]
# ## Визуализация эмбеддингов в 2D пространстве с помощью TSNE

# %%
test_embs_2D = TSNE(n_components=2).fit_transform(test_embs[:1000])
labels_for_viz = test_y[:1000]

# %%
draw_embeddings(test_embs_2D, labels_for_viz, list(range(10)))

# %% [markdown]
# ## Тестирование на новых данных

# %%
def load_and_prepare_image(fpath):
    import imageio
    from skimage.transform import resize
    img = imageio.imread(fpath, pilmode="RGB")
    img = img.astype(np.float32)/255
    img = resize(img, (28, 28), order=3, mode='reflect', anti_aliasing=True)
    img = (1. - img).astype(np.float32)
    img = np.mean(img, axis=2)
    img = np.reshape(img, (28, 28, 1))
    return img

img_a1 = load_and_prepare_image('symbol_a1.png')
img_a2 = load_and_prepare_image('symbol_a2.png')
img_b1 = load_and_prepare_image('symbol_b1.png')

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img_a1[:,:,0], cmap='gray')
ax = fig.add_subplot(1, 3, 2)
ax.imshow(img_a2[:,:,0], cmap='gray')
ax = fig.add_subplot(1, 3, 3)
ax.imshow(img_b1[:,:,0], cmap='gray')
plt.show()

# %% [markdown]
# ## Получение эмбеддингов для новых данных

# %%
new_embs = model(np.stack((img_a1, img_a2, img_b1), axis=0))

# %% [markdown]
# ## Вычисление расстояний между эмбеддингами

# %%
def diff(e1, e2):
    return np.sum((e1 - e2)**2) ** 0.5

emb1 = new_embs[0,:]
emb2 = new_embs[1,:]
emb3 = new_embs[2,:]

print('A1 <-> A2: ', diff(emb1, emb2))
print('A2 <-> B1: ', diff(emb2, emb3))
print('A1 <-> B1: ', diff(emb1, emb3))
# Out:
# A1 <-> A2:  1.8119859953164374
# A2 <-> B1:  13.205436765993923
# A1 <-> B1:  14.434933653131646
